# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris=load_iris()
df=pd.DataFrame(data=iris.data,columns=iris.feature_names)
df['species']=iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# %%
df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
# 5  setosa
# 6  setosa
# 7  setosa
# 8  setosa
# 9  setosa

# %%
x = df.iloc[:, [0, 1, 2, 3]]

# %%
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
sns.boxplot(x="species",y="petal length (cm)",data=df)
plt.show()

# %%
sns.boxplot(x="species",y="petal width (cm)",data=df)
plt.show()

# %%
import numpy as np

corr_matrix = df.iloc[:, :-1].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# K means classification

# %% [markdown]
# Method 1: Elbow method to find optimal number of clusters

# %% [markdown]
# wcss = []
#
# for i in range(1, 11):
#     kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
#     kmeans.fit(x)
#     wcss.append(kmeans.inertia_)

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=1,random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inetia_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 6
#       4 kmeans=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=1,random_state=0)
#       5 kmeans.fit(x)
# ----> 6 wcss.append(kmeans.inetia_)
#
# AttributeError: 'KMeans' object has no attribute 'inetia_'
